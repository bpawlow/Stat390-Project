# %% [markdown]
# # Data Cleaning

# %%
## Import necessary packages

import sklearn
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import Lasso, Ridge
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
## Read v4 csv dataset

data = pd.read_csv("Data/project_data_v4.csv")
display(data)
# Out:
#            id                                  program_name  \
# 0       78752   BBBS Community Based Mentoring (Year Round)
# 1       78752   BBBS Community Based Mentoring (Year Round)
# 2       78749         Youth Mentoring and Academic Supports
# 3       78749         Youth Mentoring and Academic Supports
# 4       78745  Strong, Smart, Bold Summer Camp - Girls Inc.
# ...       ...                                           ...
# 72007  148925                             Medicina Scholars
# 72008  146348                   Park Cleanup at Kelvyn Park
# 72009  146348                   Park Cleanup at Kelvyn Park
# 72010  146350                   Park Cleanup at Kelvyn Park
# 72011  146350                   Park Cleanup at Kelvyn Park
#
#                 category_name  meeting_type program_pays_participants  \
# 0            Academic Support  face_to_face                  Not Paid
# 1               Work + Career  face_to_face                  Not Paid
# 2            Academic Support  face_to_face                  Not Paid
# 3                 Music & Art  face_to_face                  Not Paid
# 4                 Music & Art  face_to_face                  Not Paid
# ...                       ...           ...                       ...
# 72007              Healthcare  face_to_face              Unknown_Code
# 72008  Helping Your Community  face_to_face                  Not Paid
# 72009                  Nature  face_to_face                  Not Paid
# 72010  Helping Your Community  face_to_face                  Not Paid
# 72011                  Nature  face_to_face                  Not Paid
#
#       program_has_scholarships program_provides_transportation  \
# 0                          YES                             YES
# 1                          YES                             YES
# 2                           NO                              NO
# 3                           NO                              NO
# 4                           NO                              NO
# ...                        ...                             ...
# 72007                       NO                             NaN
# 72008                       NO                              NO
# 72009                       NO                              NO
# 72010                       NO                              NO
# 72011                       NO                              NO
#
#       program_provides_free_food program_price  capacity  ...  \
# 0                          False          Free    2000.0  ...
# 1                          False          Free    2000.0  ...
# 2                           True          Free     100.0  ...
# 3                           True          Free     100.0  ...
# 4                          False          Free     100.0  ...
# ...                          ...           ...       ...  ...
# 72007                        NaN          Free       NaN  ...
# 72008                      False          Free       NaN  ...
# 72009                      False          Free       NaN  ...
# 72010                      False          Free       NaN  ...
# 72011                      False          Free       NaN  ...
#
#        median_household_income  median_household_income_bracket  asian_prop  \
# 0                        91907              Greater than 90,000       0.185
# 1                        91907              Greater than 90,000       0.185
# 2                        30848                 30,000 to 49,999       0.002
# 3                        30848                 30,000 to 49,999       0.002
# 4                        35719                 30,000 to 49,999       0.146
# ...                        ...                              ...         ...
# 72007                    91907              Greater than 90,000       0.185
# 72008                    54355                 50,000 to 69,999       0.023
# 72009                    54355                 50,000 to 69,999       0.023
# 72010                    54355                 50,000 to 69,999       0.023
# 72011                    54355                 50,000 to 69,999       0.023
#
#        black_prop  hispanic_prop white_prop  other_prop  cluster_location  \
# 0           0.242          0.100      0.436       0.037         West Side
# 1           0.242          0.100      0.436       0.037         West Side
# 2           0.827          0.112      0.048       0.011         West Side
# 3           0.827          0.112      0.048       0.011         West Side
# 4           0.651          0.054      0.106       0.044        South Side
# ...           ...            ...        ...         ...               ...
# 72007       0.242          0.100      0.436       0.037         West Side
# 72008       0.045          0.825      0.099       0.008    Northwest Side
# 72009       0.045          0.825      0.099       0.008    Northwest Side
# 72010       0.045          0.825      0.099       0.008    Northwest Side
# 72011       0.045          0.825      0.099       0.008    Northwest Side
#
#        simpson_diversity_index  gini_diversity_index
# 0                     0.705746              0.457548
# 1                     0.705746              0.457548
# 2                     0.301098              0.163996
# 3                     0.301098              0.163996
# 4                     0.538795              0.320879
# ...                        ...                   ...
# 72007                 0.705746              0.457548
# 72008                 0.306956              0.167507
# 72009                 0.306956              0.167507
# 72010                 0.306956              0.167507
# 72011                 0.306956              0.167507
#
# [72012 rows x 32 columns]

# %%
#Flatten dataset to only contain unique observations 

#list of column names excluding category name 

columns = list(data.columns)
columns.remove('category_name')

# Delete duplicate rows based on specific columns 
freq_data = data.drop_duplicates(subset=columns, ignore_index = True)

display(freq_data)
# Out:
#            id                                  program_name  \
# 0       78752   BBBS Community Based Mentoring (Year Round)
# 1       78749         Youth Mentoring and Academic Supports
# 2       78745  Strong, Smart, Bold Summer Camp - Girls Inc.
# 3       78745  Strong, Smart, Bold Summer Camp - Girls Inc.
# 4       78745  Strong, Smart, Bold Summer Camp - Girls Inc.
# ...       ...                                           ...
# 67494  146356        IT Adult Apprenticeship | REACH for IT
# 67495  146345                   Park Cleanup at Kelvyn Park
# 67496  148925                             Medicina Scholars
# 67497  146348                   Park Cleanup at Kelvyn Park
# 67498  146350                   Park Cleanup at Kelvyn Park
#
#                 category_name  meeting_type program_pays_participants  \
# 0            Academic Support  face_to_face                  Not Paid
# 1            Academic Support  face_to_face                  Not Paid
# 2                 Music & Art  face_to_face                  Not Paid
# 3                 Music & Art  face_to_face                  Not Paid
# 4                 Music & Art  face_to_face                  Not Paid
# ...                       ...           ...                       ...
# 67494               Computers  face_to_face        Paid, Type Unknown
# 67495  Helping Your Community  face_to_face                  Not Paid
# 67496              Healthcare  face_to_face              Unknown_Code
# 67497  Helping Your Community  face_to_face                  Not Paid
# 67498  Helping Your Community  face_to_face                  Not Paid
#
#       program_has_scholarships program_provides_transportation  \
# 0                          YES                             YES
# 1                           NO                              NO
# 2                           NO                              NO
# 3                           NO                              NO
# 4                           NO                              NO
# ...                        ...                             ...
# 67494                       NO                             NaN
# 67495                       NO                              NO
# 67496                       NO                             NaN
# 67497                       NO                              NO
# 67498                       NO                              NO
#
#       program_provides_free_food program_price  capacity  ...  \
# 0                          False          Free    2000.0  ...
# 1                           True          Free     100.0  ...
# 2                          False          Free     100.0  ...
# 3                          False          Free     100.0  ...
# 4                          False          Free     100.0  ...
# ...                          ...           ...       ...  ...
# 67494                        NaN          Free       NaN  ...
# 67495                      False          Free       NaN  ...
# 67496                        NaN          Free       NaN  ...
# 67497                      False          Free       NaN  ...
# 67498                      False          Free       NaN  ...
#
#        median_household_income  median_household_income_bracket  asian_prop  \
# 0                        91907              Greater than 90,000       0.185
# 1                        30848                 30,000 to 49,999       0.002
# 2                        35719                 30,000 to 49,999       0.146
# 3                        39030                 30,000 to 49,999       0.007
# 4                        52082                 50,000 to 69,999       0.060
# ...                        ...                              ...         ...
# 67494                    91907              Greater than 90,000       0.185
# 67495                    54355                 50,000 to 69,999       0.023
# 67496                    91907              Greater than 90,000       0.185
# 67497                    54355                 50,000 to 69,999       0.023
# 67498                    54355                 50,000 to 69,999       0.023
#
#        black_prop  hispanic_prop white_prop  other_prop  cluster_location  \
# 0           0.242          0.100      0.436       0.037         West Side
# 1           0.827          0.112      0.048       0.011         West Side
# 2           0.651          0.054      0.106       0.044        South Side
# 3           0.896          0.033      0.041       0.023        South Side
# 4           0.660          0.022      0.209       0.048        South Side
# ...           ...            ...        ...         ...               ...
# 67494       0.242          0.100      0.436       0.037         West Side
# 67495       0.045          0.825      0.099       0.008    Northwest Side
# 67496       0.242          0.100      0.436       0.037         West Side
# 67497       0.045          0.825      0.099       0.008    Northwest Side
# 67498       0.045          0.825      0.099       0.008    Northwest Side
#
#        simpson_diversity_index  gini_diversity_index
# 0                     0.705746              0.457548
# 1                     0.301098              0.163996
# 2                     0.538795              0.320879
# 3                     0.193836              0.102134
# 4                     0.514331              0.303100
# ...                        ...                   ...
# 67494                 0.705746              0.457548
# 67495                 0.306956              0.167507
# 67496                 0.705746              0.457548
# 67497                 0.306956              0.167507
# 67498                 0.306956              0.167507
#
# [67499 rows x 32 columns]

# %%
# Discard programs where the minimum age is over 25

display(data[data['min_age'] > 25])

under_25_data = data[data['min_age'] <= 25]
# Out:
#            id                                       program_name  \
# 68      77506          Tennis - Senior Round Robin at McFetridge
# 1973    77507          Tennis - Senior Round Robin at McFetridge
# 2118    77508          Tennis - Senior Round Robin at McFetridge
# 2122    77511          Tennis - Senior Round Robin at McFetridge
# 2124    77509          Tennis - Senior Round Robin at McFetridge
# ...       ...                                                ...
# 25059  105802                                       Medicare 101
# 38618  121945  Power of Attorney Workshop: For Property, Heal...
# 45630  134633        Retired and Senior Volunteer Program (RSVP)
# 45631  134634        Retired and Senior Volunteer Program (RSVP)
# 62431  145818                                   Senior Saturdays
#
#                 category_name  meeting_type program_pays_participants  \
# 68          Sports + Wellness  face_to_face                  Not Paid
# 1973        Sports + Wellness  face_to_face                  Not Paid
# 2118        Sports + Wellness  face_to_face                  Not Paid
# 2122        Sports + Wellness  face_to_face                  Not Paid
# 2124        Sports + Wellness  face_to_face                  Not Paid
# ...                       ...           ...                       ...
# 25059          Managing Money  face_to_face                  Not Paid
# 38618          Managing Money  face_to_face                  Not Paid
# 45630  Helping Your Community  face_to_face              Unknown_Code
# 45631  Helping Your Community  face_to_face              Unknown_Code
# 62431             Music & Art  face_to_face                  Not Paid
#
#       program_has_scholarships program_provides_transportation  \
# 68                          NO                              NO
# 1973                        NO                              NO
# 2118                        NO                              NO
# 2122                        NO                              NO
# 2124                        NO                              NO
# ...                        ...                             ...
# 25059                       NO                              NO
# 38618                       NO                              NO
# 45630                       NO                             NaN
# 45631                       NO                             NaN
# 62431                       NO                              NO
#
#       program_provides_free_food program_price  capacity  ...  \
# 68                         False   $50 or Less       NaN  ...
# 1973                       False   $50 or Less       NaN  ...
# 2118                       False   $50 or Less       NaN  ...
# 2122                       False   $50 or Less       NaN  ...
# 2124                       False   $50 or Less       NaN  ...
# ...                          ...           ...       ...  ...
# 25059                      False          Free      99.0  ...
# 38618                      False          Free       NaN  ...
# 45630                        NaN          Free       NaN  ...
# 45631                        NaN          Free       NaN  ...
# 62431                      False          Free      99.0  ...
#
#        median_household_income  median_household_income_bracket  asian_prop  \
# 68                       71513                 70,000 to 89,999       0.086
# 1973                     71513                 70,000 to 89,999       0.086
# 2118                     71513                 70,000 to 89,999       0.086
# 2122                     71513                 70,000 to 89,999       0.086
# 2124                     71513                 70,000 to 89,999       0.086
# ...                        ...                              ...         ...
# 25059                    88578                 70,000 to 89,999       0.044
# 38618                    60301                 50,000 to 69,999       0.263
# 45630                    57095                 50,000 to 69,999       0.001
# 45631                    57095                 50,000 to 69,999       0.001
# 62431                    78910                 70,000 to 89,999       0.010
#
#        black_prop  hispanic_prop white_prop  other_prop    cluster_location  \
# 68          0.027          0.412      0.440       0.035      Northwest Side
# 1973        0.027          0.412      0.440       0.035      Northwest Side
# 2118        0.027          0.412      0.440       0.035      Northwest Side
# 2122        0.027          0.412      0.440       0.035      Northwest Side
# 2124        0.027          0.412      0.440       0.035      Northwest Side
# ...           ...            ...        ...         ...                 ...
# 25059       0.007          0.155      0.769       0.026      Far North Side
# 38618       0.022          0.187      0.487       0.040      Far North Side
# 45630       0.934          0.044      0.009       0.012  Far Southeast Side
# 45631       0.934          0.044      0.009       0.012  Far Southeast Side
# 62431       0.046          0.528      0.409       0.007      Southwest Side
#
#        simpson_diversity_index  gini_diversity_index
# 68                    0.627306              0.389513
# 1973                  0.627306              0.389513
# 2118                  0.627306              0.389513
# 2122                  0.627306              0.389513
# 2124                  0.627306              0.389513
# ...                        ...                   ...
# 25059                 0.381953              0.213840
# 38618                 0.656609              0.414004
# 45630                 0.125482              0.064843
# 45631                 0.125482              0.064843
# 62431                 0.551670              0.330426
#
# [102 rows x 32 columns]

# %%
# Identify proper predictor and feature variables and split train/test 

X = data[...]
y = data[...]

sc = StandardScaler()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

sc.fit(X_train)

X_train_scaled = sc.transform(X_train)
X_test_scaled = sc.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:108, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: Ellipsis
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Identify proper predictor and feature variables and split train/test
# ----> 3 X = data[...]
#       4 y = data[...]
#       6 sc = StandardScaler()
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3458, in DataFrame.__getitem__(self, key)
#    3456 if self.columns.nlevels > 1:
#    3457     return self._getitem_multilevel(key)
# -> 3458 indexer = self.columns.get_loc(key)
#    3459 if is_integer(indexer):
#    3460     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3363, in Index.get_loc(self, key, method, tolerance)
#    3361         return self._engine.get_loc(casted_key)
#    3362     except KeyError as err:
# -> 3363         raise KeyError(key) from err
#    3365 if is_scalar(key) and isna(key) and not self.hasnans:
#    3366     raise KeyError(key)
#
# KeyError: Ellipsis

# %%
# Use Lasso and Ridge regression to find which features best predict and affect the data

#Lasso regression
lasso = LassoCV(cv=5)
lasso.fit(X_train, y_train)
alpha = lasso.alpha_

print(f"Optimal alpha: {alpha:.4f}")

lasso_model = Lasso(alpha=alpha)
lasso_model.fit(X_train, y_train)

selected_features = np.where(lasso_model.coef_ != 0)[0]
print(f"Selected features: {selected_features}")


#ridge regression
ridge = RidgeCV(cv=5)
ridge.fit(X_train, y_train)
alpha = ridge.alpha_

print(f"Optimal alpha: {alpha:.4f}")

ridge_model = Ridge(alpha=alpha)
ridge_model.fit(X_train, y_train)

selected_features = np.where(ridge_model.coef_ != 0)[0]
print(f"Selected features: {selected_features}")
